# %% [markdown]
# <h1>Question 3</h1>

# %% [markdown]
# <span style="color:red"> 3.(a) Suppose X<sub>ji</sub> for i=1,2,...,J is a collection of data on J popilations. Let b be a p-dimensional vector and consider the days z<sub>ji</sub> = b'X<sub>ji</sub> for i=1,2,...,n<sub>j</sub> and j=1,2,...,J. <p>Write a formula in terms of the z-data across the J groups.</p></span>

# %% [markdown]
# z = z<sup>2</sup> lol

# %% [markdown]
#    <span style="color:red"> (b) How is (a) used in the development of linear discriminant analysis? </span>

# %% [markdown]
# Optimize it for the choices over the vector

# %% [markdown]
#    <span style="color:red"> (c) Carry out a linear discriminant analysis on Fisher's iris data (available in R) and prepare boxplots of the first and secon discriminant variables(z-scores) as a function of species </span>

# %%
library(MASS)

# %%
x = as.matrix(iris[,1:4])

# %%
y = iris[,5]

# %%
model = lda(x,y)
model
# Out:
# Call:
# lda(x, grouping = y)
#
# Prior probabilities of groups:
#     setosa versicolor  virginica
#  0.3333333  0.3333333  0.3333333
#
# Group means:
#            Sepal.Length Sepal.Width Petal.Length Petal.Width
# setosa            5.006       3.428        1.462       0.246
# versicolor        5.936       2.770        4.260       1.326
# virginica         6.588       2.974        5.552       2.026
#
# Coefficients of linear discriminants:
#                     LD1         LD2
# Sepal.Length  0.8293776  0.02410215
# Sepal.Width   1.5344731  2.16452123
# Petal.Length -2.2012117 -0.93192121
# Petal.Width  -2.8104603  2.83918785
#
# Proportion of trace:
#    LD1    LD2
# 0.9912 0.0088

# %%
model$scaling
# Out:
#                     LD1         LD2
# Sepal.Length  0.8293776  0.02410215
# Sepal.Width   1.5344731  2.16452123
# Petal.Length -2.2012117 -0.93192121
# Petal.Width  -2.8104603  2.83918785

# %% [markdown]
# Transform the observations to discriminant functions by multiplying the data by the scaling matrix

# %%
z = x %*% o$scaling

# %% [markdown]
# Boxplot of the first linear discriminator, very good separation

# %%
boxplot(z[,1]~y)
# Out:
# plot without title

# %% [markdown]
# Boxplot of the second linear discriminator

# %%
boxplot(z[,2]~y)
# Out:
# plot without title

# %% [markdown]
#    <span style="color:red"> (d) Use the lda() function in R to evaluate the cross-validation predictions of the true species class for each observation in the iris data. Produce a table summarizing the numbers of each species that are classified into the three species classes. What percent of each species are correctly classified? </span>

# %%
modelPred = predict(model,CV=T)
modelPred$class
yhatcv <- modelPred$class
# Out:
#   [1] setosa     setosa     setosa     setosa     setosa     setosa
#   [7] setosa     setosa     setosa     setosa     setosa     setosa
#  [13] setosa     setosa     setosa     setosa     setosa     setosa
#  [19] setosa     setosa     setosa     setosa     setosa     setosa
#  [25] setosa     setosa     setosa     setosa     setosa     setosa
#  [31] setosa     setosa     setosa     setosa     setosa     setosa
#  [37] setosa     setosa     setosa     setosa     setosa     setosa
#  [43] setosa     setosa     setosa     setosa     setosa     setosa
#  [49] setosa     setosa     versicolor versicolor versicolor versicolor
#  [55] versicolor versicolor versicolor versicolor versicolor versicolor
#  [61] versicolor versicolor versicolor versicolor versicolor versicolor
#  [67] versicolor versicolor versicolor versicolor virginica  versicolor
#  [73] versicolor versicolor versicolor versicolor versicolor versicolor
# ...

# %%
table(y,yhatcv)
# Out:
#             yhatcv
# y            setosa versicolor virginica
#   setosa         50          0         0
#   versicolor      0         48         2
#   virginica       0          1        49

# %% [markdown]
# <p>Setosa: 100%
# correct</p>
# <p>Versicolor: 96%
# correct </p>
# <p>Virginica: 98%
# correct </p>
